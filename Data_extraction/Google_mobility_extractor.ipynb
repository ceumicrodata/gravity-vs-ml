# %% [markdown]
# # This notebooks extracts input data from Google mobility dataset

# %%
import pandas as pd
import numpy
import requests
import json
import codecs
import pickle
from collections import defaultdict
from datetime import datetime
from dateutil.relativedelta import relativedelta
import time

# %%
years = [2020, 2021, 2022]
mobility_data_dict = {}
mobility_data_list = []

for year in years:
    mobility = pd.read_csv(f'../Input_datasets/Google_mobility_flow_prediction/Large_files/{year}_US_Region_Mobility_Report.csv', dtype=object)

    # Get state level info
    mobility = mobility[mobility["iso_3166_2_code"].isnull()==False]

    # US-DC (District of Columbia) is not state so remove
    #print(len(mobility_2020["iso_3166_2_code"].unique()))
    mobility = mobility[mobility["iso_3166_2_code"]!="US-DC"]

    # Drop columns that are not informative
    mobility.drop(columns=["census_fips_code", "sub_region_2", "metro_area", "place_id"], inplace=True)

    mobility_data_dict[year] = mobility
    mobility_data_list.append(mobility)

mobility_data = pd.concat(mobility_data_list)
mobility_data.sort_values(by=["sub_region_1", "date"], inplace=True)

mobility_data.to_csv("../Input_datasets/Google_mobility_flow_prediction/Google_mobility_data.csv", index=False)

# %%
mobility_data
# Out:
#        country_region_code country_region sub_region_1 iso_3166_2_code  \
# 321                     US  United States      Alabama           US-AL
# 322                     US  United States      Alabama           US-AL
# 323                     US  United States      Alabama           US-AL
# 324                     US  United States      Alabama           US-AL
# 325                     US  United States      Alabama           US-AL
# ...                    ...            ...          ...             ...
# 742701                  US  United States      Wyoming           US-WY
# 742702                  US  United States      Wyoming           US-WY
# 742703                  US  United States      Wyoming           US-WY
# 742704                  US  United States      Wyoming           US-WY
# 742705                  US  United States      Wyoming           US-WY
#
#               date retail_and_recreation_percent_change_from_baseline  \
# 321     2020-02-15                                                  5
# 322     2020-02-16                                                  0
# 323     2020-02-17                                                  3
# 324     2020-02-18                                                 -4
# 325     2020-02-19                                                  4
# ...            ...                                                ...
# 742701  2022-10-11                                                  3
# 742702  2022-10-12                                                  0
# 742703  2022-10-13                                                  3
# 742704  2022-10-14                                                 -2
# 742705  2022-10-15                                                 -2
#
#        grocery_and_pharmacy_percent_change_from_baseline  \
# 321                                                    2
# 322                                                   -2
# 323                                                    0
# 324                                                   -3
# 325                                                    1
# ...                                                  ...
# 742701                                                 2
# 742702                                                -1
# 742703                                                 2
# 742704                                                 1
# 742705                                                -1
#
#        parks_percent_change_from_baseline  \
# 321                                    39
# 322                                    -7
# 323                                    17
# 324                                   -11
# 325                                     6
# ...                                   ...
# 742701                                 75
# 742702                                 81
# 742703                                 90
# 742704                                 97
# 742705                                109
#
#        transit_stations_percent_change_from_baseline  \
# 321                                                7
# 322                                                3
# 323                                                7
# 324                                               -1
# 325                                                4
# ...                                              ...
# 742701                                            16
# 742702                                            18
# 742703                                            23
# 742704                                            31
# 742705                                            25
#
#        workplaces_percent_change_from_baseline  \
# 321                                          2
# 322                                         -1
# 323                                        -17
# 324                                          1
# 325                                          1
# ...                                        ...
# 742701                                     -14
# 742702                                     -16
# 742703                                     -15
# 742704                                     -13
# 742705                                      -9
#
#        residential_percent_change_from_baseline
# 321                                          -1
# 322                                           1
# 323                                           4
# 324                                           2
# 325                                           0
# ...                                         ...
# 742701                                        1
# 742702                                        0
# 742703                                        0
# 742704                                        0
# 742705                                       -1
#
# [48700 rows x 11 columns]
